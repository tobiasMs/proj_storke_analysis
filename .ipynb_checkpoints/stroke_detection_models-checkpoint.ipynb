# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('healthcare-dataset-stroke-data.csv')
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
print(df['stroke'].value_counts())
# Out:
# stroke
# 0    4861
# 1     249
# Name: count, dtype: int64

# %%
df_class_1 = df[df['stroke'] == 1]
number_class_1 = len(df_class_1)
df_class_0 = df[df['stroke'] == 0].sample(number_class_1)

final_df = pd.concat([df_class_1,
                         	df_class_0])

print(final_df.shape)
# Out:
# (498, 12)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 498 entries, 0 to 4886
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 498 non-null    int64
#  1   gender             498 non-null    object
#  2   age                498 non-null    float64
#  3   hypertension       498 non-null    int64
#  4   heart_disease      498 non-null    int64
#  5   ever_married       498 non-null    object
#  6   work_type          498 non-null    object
#  7   Residence_type     498 non-null    object
#  8   avg_glucose_level  498 non-null    float64
#  9   bmi                449 non-null    float64
#  10  smoking_status     498 non-null    object
#  11  stroke             498 non-null    int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 50.6+ KB

# %%
#Data manipulation untuk tipe data object supaya mudah untuk dilakukan manipulation
final_df['gender'] = final_df['gender'].map({'Male': 0, 'Female': 1, 'Other': 2})
final_df['ever_married'] = final_df['ever_married'].map({'No': 0, 'Yes': 1})
final_df['Residence_type'] = final_df['Residence_type'].map({'Rural': 0, 'Urban': 1})
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 498 entries, 0 to 4886
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 498 non-null    int64
#  1   gender             498 non-null    int64
#  2   age                498 non-null    float64
#  3   hypertension       498 non-null    int64
#  4   heart_disease      498 non-null    int64
#  5   ever_married       498 non-null    int64
#  6   work_type          498 non-null    object
#  7   Residence_type     498 non-null    int64
#  8   avg_glucose_level  498 non-null    float64
#  9   bmi                449 non-null    float64
#  10  smoking_status     498 non-null    object
#  11  stroke             498 non-null    int64
# dtypes: float64(3), int64(7), object(2)
# memory usage: 50.6+ KB

# %%
#Cek apakah ada data null
print(final_df.isnull().sum())
# Out:
# id                    0
# gender                0
# age                   0
# hypertension          0
# heart_disease         0
# ever_married          0
# work_type             0
# Residence_type        0
# avg_glucose_level     0
# bmi                  49
# smoking_status        0
# stroke                0
# dtype: int64

# %%
# Manipulate data yang null dengan mean 
final_df.fillna(final_df.mean(numeric_only=True), inplace=True)

# Untuk kolom yang tipe datanya object, diisi dengan data yang sering muncul (median)
for col in final_df.select_dtypes(include='object'):
    final_df[col].fillna(final_df[col].mode()[0], inplace=True)

final_df.head()
# Out:
# C:\Users\Tobias\AppData\Local\Temp\ipykernel_19360\2595137788.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   final_df[col].fillna(final_df[col].mode()[0], inplace=True)
#       id  gender   age  hypertension  heart_disease  ever_married  \
# 0   9046       0  67.0             0              1             1
# 1  51676       1  61.0             0              0             1
# 2  31112       0  80.0             0              1             1
# 3  60182       1  49.0             0              0             1
# 4   1665       1  79.0             1              0             1
#
#        work_type  Residence_type  avg_glucose_level        bmi  \
# 0        Private               1             228.69  36.600000
# 1  Self-employed               0             202.21  29.767261
# 2        Private               0             105.92  32.500000
# 3        Private               1             171.23  34.400000
# 4  Self-employed               0             174.12  24.000000
#
#     smoking_status  stroke
# 0  formerly smoked       1
# 1     never smoked       1
# 2     never smoked       1
# 3           smokes       1
# 4     never smoked       1

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 498 entries, 0 to 4886
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 498 non-null    int64
#  1   gender             498 non-null    int64
#  2   age                498 non-null    float64
#  3   hypertension       498 non-null    int64
#  4   heart_disease      498 non-null    int64
#  5   ever_married       498 non-null    int64
#  6   work_type          498 non-null    object
#  7   Residence_type     498 non-null    int64
#  8   avg_glucose_level  498 non-null    float64
#  9   bmi                498 non-null    float64
#  10  smoking_status     498 non-null    object
#  11  stroke             498 non-null    int64
# dtypes: float64(3), int64(7), object(2)
# memory usage: 50.6+ KB

# %%
#Ubah data yang tipe object 
final_df['work_type'].unique()
# Out:
# array(['Private', 'Self-employed', 'Govt_job', 'children', 'Never_worked'],
#       dtype=object)

# %%
# Buat dictionary untuk mapping
work_type_mapping = {
    'Private': 1,
    'Self-employed': 2,
    'Govt_job': 3,
    'children': 4,
    'Never_worked': 5
}

# Terapkan mapping ke kolom work_type
final_df['work_type'] = final_df['work_type'].map(work_type_mapping)

# %%
#Ubah data smoking status yang tipe object 
final_df['smoking_status'].unique()
# Out:
# array(['formerly smoked', 'never smoked', 'smokes', 'Unknown'],
#       dtype=object)

# %%
# Langkah 1: Hitung modus dari 3 kategori valid (tidak termasuk 'Unknown')
valid_smoking = final_df[final_df['smoking_status'] != 'Unknown']['smoking_status']
most_common = valid_smoking.mode()[0]

# Ganti 'Unknown' dengan nilai modus
final_df['smoking_status'] = final_df['smoking_status'].replace('Unknown', most_common)

# Langkah 2: Mapping manual ke angka
smoking_mapping = {
    'formerly smoked': 1,
    'never smoked': 2,
    'smokes': 3
}

final_df['smoking_status'] = final_df['smoking_status'].map(smoking_mapping)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
X = final_df.drop('stroke', axis=1)
normalized_X = scaler.fit_transform(X)

# %%
#Split Train, Test 
from sklearn.model_selection import train_test_split

y = final_df['stroke']
r_state_1 = 2023
t_size_1 = 0.33

X_train, X_test, y_train, y_test = train_test_split(normalized_X, y,
                                                	test_size=t_size_1,
                                                	random_state=r_state_1,
                                                	stratify=y)

# %%
from sklearn.impute import SimpleImputer

# Just impute everything (assuming X_train has only numeric data now)
imputer = SimpleImputer(strategy='mean')
X_train = imputer.fit_transform(X_train)
X_test = imputer.transform(X_test)

# %%
#Random Forest Modeling

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# Define the model
random_forest_model = RandomForestClassifier()
# Fit the random search object to the data
random_forest_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
#Hasil akurasi menggunakan randomforest
from sklearn.metrics import accuracy_score,classification_report
y_pred = random_forest_model.predict(X_test)

# Get the performance
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy) 
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7878787878787878
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.77      0.78        82
#            1       0.78      0.81      0.79        83
#
#     accuracy                           0.79       165
#    macro avg       0.79      0.79      0.79       165
# weighted avg       0.79      0.79      0.79       165

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
# Predict menggunakan conf matrix
y_pred = random_forest_model.predict(X_test)
cm_randomforest = confusion_matrix(y_test, y_pred)

# %%
import matplotlib.pyplot as plt
# Tampilkan Conf Matrix
plt.figure(figsize=(8, 8))
sns.heatmap(cm_randomforest, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
# Hasil akurasi menggunakan random forest 
# Untuk meningkatkan akurasinya, karena datanya inbalance bisa lakukan balancing data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
X = final_df.drop('stroke', axis=1)
normalized_X = scaler.fit_transform(X)
y = final_df['stroke']

# %%
#Modeling menggunakan logisitc regression
from sklearn.linear_model import LogisticRegression

r_state_2 = 870
t_size_2 = 0.52

X_train, X_val, y_train, y_val = train_test_split(
                                            	normalized_X, y,
                                            	test_size=t_size_2,
                                            	random_state=r_state_2)

# %%
X_val = pd.DataFrame(X_val)
X_test = pd.DataFrame(X_test)

lr_model = LogisticRegression()
lr_model.fit(X_val, y_val)

# Evaluasi model di test set
lr_model.score(X_test, y_test)
# Out:
# 0.8121212121212121

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
# Predict menggunakan conf matrix
y_pred = lr_model.predict(X_test)
cm_lr = confusion_matrix(y_test, y_pred)

# %%
import matplotlib.pyplot as plt
# Tampilkan Conf Matrix
plt.figure(figsize=(8, 8))
sns.heatmap(cm_lr, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
## Using Deep Learning Models

# %%
#Import DL 
from keras.layers import Dense, Dropout
from keras.models import Sequential
r_state_3 = 2000
t_size_3 = 0.4

X_train, X_val, y_train, y_val = train_test_split(
                                            	X_train, y_train,
                                            	test_size=t_size_3,
                                            	random_state=r_state_3)

# %%
model_seq = Sequential()
model_seq.add(Dense(16, activation='relu', input_dim=X_train.shape[1]))
model_seq.add(Dense(64, activation="relu"))
model_seq.add(Dense(128, activation="relu"))
model_seq.add(Dropout(0.30))
model_seq.add(Dense(64, activation="relu"))
model_seq.add(Dense(8, activation="relu"))
model_seq.add(Dense(1, activation="sigmoid"))
# Out:
# C:\Users\Tobias\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#Compile model
model_seq.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
history = model_seq.fit(X_train, y_train, epochs=79, batch_size=10, validation_split=0.46, verbose=1)
# Out:
# Epoch 1/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.4030 - loss: 0.6955 - val_accuracy: 0.6364 - val_loss: 0.6919
# Epoch 2/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5671 - loss: 0.6929 - val_accuracy: 0.5455 - val_loss: 0.6925
# Epoch 3/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5623 - loss: 0.6932 - val_accuracy: 0.5303 - val_loss: 0.6926
# Epoch 4/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5853 - loss: 0.6913 - val_accuracy: 0.5606 - val_loss: 0.6924
# Epoch 5/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6095 - loss: 0.6916 - val_accuracy: 0.4848 - val_loss: 0.6915
# Epoch 6/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6197 - loss: 0.6885 - val_accuracy: 0.4848 - val_loss: 0.6909
# Epoch 7/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5146 - loss: 0.6912 - val_accuracy: 0.5455 - val_loss: 0.6914
# Epoch 8/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6749 - loss: 0.6858 - val_accuracy: 0.5455 - val_loss: 0.6908
# Epoch 9/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6473 - loss: 0.6852 - val_accuracy: 0.5758 - val_loss: 0.6896
# Epoch 10/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6183 - loss: 0.6884 - val_accuracy: 0.5909 - val_loss: 0.6887
# Epoch 11/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6158 - loss: 0.6827 - val_accuracy: 0.6061 - val_loss: 0.6873
# Epoch 12/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6716 - loss: 0.6812 - val_accuracy: 0.6364 - val_loss: 0.6862
# Epoch 13/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7400 - loss: 0.6758 - val_accuracy: 0.6364 - val_loss: 0.6853
# Epoch 14/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5798 - loss: 0.6828 - val_accuracy: 0.6212 - val_loss: 0.6854
# Epoch 15/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5930 - loss: 0.6841 - val_accuracy: 0.6061 - val_loss: 0.6854
# Epoch 16/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6715 - loss: 0.6606 - val_accuracy: 0.6061 - val_loss: 0.6840
# Epoch 17/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5490 - loss: 0.6737 - val_accuracy: 0.6515 - val_loss: 0.6812
# Epoch 18/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6682 - loss: 0.6615 - val_accuracy: 0.6212 - val_loss: 0.6795
# Epoch 19/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7657 - loss: 0.6461 - val_accuracy: 0.6364 - val_loss: 0.6770
# Epoch 20/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6103 - loss: 0.6643 - val_accuracy: 0.6364 - val_loss: 0.6770
# Epoch 21/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7089 - loss: 0.6468 - val_accuracy: 0.6364 - val_loss: 0.6725
# Epoch 22/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5405 - loss: 0.6673 - val_accuracy: 0.6515 - val_loss: 0.6713
# Epoch 23/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5584 - loss: 0.6650 - val_accuracy: 0.6364 - val_loss: 0.6717
# Epoch 24/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.
79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7093 - loss: 0.5056 - val_accuracy: 0.6515 - val_loss: 0.6641
# Epoch 55/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8104 - loss: 0.4618 - val_accuracy: 0.6212 - val_loss: 0.6703
# Epoch 56/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7460 - loss: 0.4909 - val_accuracy: 0.6818 - val_loss: 0.6574
# Epoch 57/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8250 - loss: 0.4796 - val_accuracy: 0.6515 - val_loss: 0.6686
# Epoch 58/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8175 - loss: 0.4551 - val_accuracy: 0.6818 - val_loss: 0.6690
# Epoch 59/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8159 - loss: 0.4353 - val_accuracy: 0.6818 - val_loss: 0.6712
# Epoch 60/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7957 - loss: 0.4312 - val_accuracy: 0.6364 - val_loss: 0.6655
# Epoch 61/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7860 - loss: 0.4649 - val_accuracy: 0.6818 - val_loss: 0.6836
# Epoch 62/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7903 - loss: 0.4513 - val_accuracy: 0.6515 - val_loss: 0.6903
# Epoch 63/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7629 - loss: 0.5156 - val_accuracy: 0.6667 - val_loss: 0.6796
# Epoch 64/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8131 - loss: 0.4494 - val_accuracy: 0.6667 - val_loss: 0.6830
# Epoch 65/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7754 - loss: 0.4694 - val_accuracy: 0.6667 - val_loss: 0.6847
# Epoch 66/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7713 - loss: 0.4558 - val_accuracy: 0.6364 - val_loss: 0.6948
# Epoch 67/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7930 - loss: 0.4260 - val_accuracy: 0.6364 - val_loss: 0.6802
# Epoch 68/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8305 - loss: 0.4029 - val_accuracy: 0.6515 - val_loss: 0.6934
# Epoch 69/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7983 - loss: 0.3996 - val_accuracy: 0.6364 - val_loss: 0.7240
# Epoch 70/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7466 - loss: 0.4992 - val_accuracy: 0.6515 - val_loss: 0.7150
# Epoch 71/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8290 - loss: 0.3869 - val_accuracy: 0.6364 - val_loss: 0.7224
# Epoch 72/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7694 - loss: 0.4398 - val_accuracy: 0.6212 - val_loss: 0.7168
# Epoch 73/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8320 - loss: 0.4463 - val_accuracy: 0.6061 - val_loss: 0.7422
# Epoch 74/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6943 - loss: 0.5311 - val_accuracy: 0.6061 - val_loss: 0.7120
# Epoch 75/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7990 - loss: 0.4643 - val_accuracy: 0.6061 - val_loss: 0.7286
# Epoch 76/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8290 - loss: 0.3951 - val_accuracy: 0.6515 - val_loss: 0.7664
# Epoch 77/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8501 - loss: 0.3717 - val_accuracy: 0.6212 - val_loss: 0.7540
# Epoch 78/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7532 - loss: 0.4098 - val_accuracy: 0.6515 - val_loss: 0.7577
# Epoch 79/79
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7301 - loss: 0.4610 - val_accuracy: 0.6212 - val_loss: 0.7150

# %%
loss, accuracy = model_seq.evaluate(X_test, y_test)

print("Model accuracy: %.2f"% (accuracy * 100))
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6431 - loss: 0.6175
# Model accuracy: 70.30

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
# Predict menggunakan conf matrix
# Prediksi probabilitas
y_pred_prob = model_seq.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Buat confusion matrix
cm_seq = confusion_matrix(y_test, y_pred)

# Tampilkan confusion matrix dengan heatmap
plt.figure(figsize=(6, 6))
sns.heatmap(cm_seq, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix - Deep Learning Model')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
